# %%
from jira_module import *

# %%
main_df= fetched_data()
main_df
#main_df.head()
# Out:
# d:\Django_projects\api_env\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'alightdevelopmentandit.atlassian.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Extracting epics...
# d:\Django_projects\api_env\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'alightdevelopmentandit.atlassian.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
df = life_df(main_df, lifecyle='qa')
df
# Out:
#              key issue_id issue_parent_ticket issue_parent_ticket_summary  \
# 5   ADAMIGR-1473   136487          ADAMIGR-33           ACE Release 2.4.1
# 6   ADAMIGR-1467   136462          ADAMIGR-33           ACE Release 2.4.1
# 8   ADAMIGR-1437   134372          ADAMIGR-33           ACE Release 2.4.1
# 9   ADAMIGR-1425   134167          ADAMIGR-33           ACE Release 2.4.1
# 10  ADAMIGR-1419   134160          ADAMIGR-33           ACE Release 2.4.1
# 11  ADAMIGR-1413   134154          ADAMIGR-33           ACE Release 2.4.1
# 12  ADAMIGR-1407   134145          ADAMIGR-33           ACE Release 2.4.1
# 13  ADAMIGR-1401   134139          ADAMIGR-33           ACE Release 2.4.1
# 14  ADAMIGR-1395   134133          ADAMIGR-33           ACE Release 2.4.1
# 15  ADAMIGR-1389   134127          ADAMIGR-33           ACE Release 2.4.1
# 16  ADAMIGR-1383   134120          ADAMIGR-33           ACE Release 2.4.1
# 17  ADAMIGR-1377   134113          ADAMIGR-33           ACE Release 2.4.1
# ...

# %%
df_qc = create_df_with_busrule(main_df, bus_rules='bus_rules.json', lifecycle='hello')
df_qc
# Out:
# This business does not match with any lifecycle
